# %%
#clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# !git reset --hard 886f1c03d839575afecb059accf74296fad395b6
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12390, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 12390 (delta 1), reused 7 (delta 1), pack-reused 12383
# Receiving objects: 100% (12390/12390), 11.56 MiB | 25.67 MiB/s, done.
# Resolving deltas: 100% (8613/8613), done.
# /content/yolov5/yolov5
# HEAD is now at 886f1c0 DDP after autoanchor reorder (#2421)

# %%
#install dependencies
# !pip install -qr requirements.txt 
import torch

from IPython.display import Image, clear_output  
from utils.google_utils import gdrive_download  #to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.10.0+cu111 _CudaDeviceProperties(name='Tesla K80', major=3, minor=7, total_memory=11441MB, multi_processor_count=13)

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="5sz3EfvZtN6L2isPTsUT")
project = rf.workspace("devanshi-parmar").project("bank-extraction")
dataset = project.version(1).download("yolov5")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.7/dist-packages (0.2.4)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.7/dist-packages (from roboflow) (7.1.2)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.63.0)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.4.7)
# Requirement already satisfied: kiwisolver==1.3.1 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.3.1)
# Requirement already satisfied: urllib3==1.26.6 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.26.6)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from roboflow) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.27.1)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.21.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from roboflow) (3.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: opencv-python>=4.1.2 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.1.2.30)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.20.0)
# Requirement already satisfied: certifi==2021.5.30 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2021.5.30)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.9.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.15.0)
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (from roboflow) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests->roboflow) (2.0.12)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Bank-Extraction-1 to yolov5pytorch: 100% [1183474 / 1183474] bytes
# Extracting Dataset Version Zip to Bank-Extraction-1 in yolov5pytorch:: 100%|██████████| 88/88 [00:00<00:00, 1329.41it/s]

# %%
# %cat {dataset.location}/data.yaml
# Out:
# names:
# - Account Number
# - Account Type
# - Balance
# - Bank Details
# - Credits
# - Debits
# - Deposits
# - Name
# - Total Balance
# - Transaction Particulars
# - Withdrawals
# nc: 11
# train: Bank-Extraction-1/train/images
# val: Bank-Extraction-1/valid/images

# %% [markdown]
# Yaml script that defines the parameters for our model like the number of classes, anchors, and each layer.

# %%
#define number of classes based on YAML
import yaml
with open(dataset.location + "/data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
# %cat /content/yolov5/models/yolov5s.yaml
# Out:
# # parameters
# nc: 80  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, C3, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate /content/yolov5/models/custom_yolov5s.yaml
#
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %% [markdown]
# Pass arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights.
# - **name:** result names
# - **nosave:** only save the final checkpoint
# - **cache:** cache images for faster training

# %%
# train yolov5s on custom data for 200 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --img 416 --batch 16 --epochs 200 --data {dataset.location}/data.yaml --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# Out:
# /content/yolov5
# github: ⚠️ WARNING: code is out of date by 942 commits. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# YOLOv5 v4.0-126-g886f1c0 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=True, cfg='./models/custom_yolov5s.yaml', data='/content/yolov5/Bank-Extraction-1/data.yaml', device='', entity=None, epochs=200, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[416, 416], linear_lr=False, local_rank=-1, log_artifacts=False, log_imgs=16, multi_scale=False, name='yolov5s_results', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov5s_results', single_cls=False, sync_bn=False, total_batch_size=16, weights='', workers=8, world_size=1)
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1     43152  models.yolo.Detect                      [11, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 283 layers, 7282064 parameters, 7282064 gradients, 16.9 GFLOPS
#
# Scaled weight_decay = 0.0005
# Optimizer groups: 62 .bias, 70 conv.weight, 59 other
# train: Scanning 'Bank-Extraction-1/train/labels' for images and labels... 29 found, 0 missing, 0 empty, 0 corrupted: 100% 29/29 [00:00<00:00, 914.93it/s]
# train: New cache created: Bank-Extraction-1/train/labels.cache
# train: Caching images (0.0GB): 100% 29/29 [00:00<00:00, 541.01it/s]
# val: Scanning 'Bank-Extraction-1/valid/labels' for images and labels... 4 found, 0 missing, 0 empty, 0 corrupted: 100% 4/4 [00:00<00:00, 814.90it/s]
# val: New cache created: Bank-Extraction-1/valid/labels.cache
# val: Caching images (0.0GB): 100% 4/4 [00:00<00:00, 330.36it/s]
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 2.65, Best Possible Recall (BPR) = 0.8929. Attempting to improve anchors, please wait...
# autoanchor: Running kmeans for 9 anchors on 168 points...
# autoanchor: thr=0.25: 1.0000 best possible recall, 2.73 anchors past thr
# autoanchor: n=9, img_size=416, metric_all=0.248/0.750-mean/best, past_thr=0.556-mean: 56,10,  36,17,  109,36,  160,41,  35,224,  289,39,  34,363,  152,226,  151,364
# autoanchor: Evolving anchors with Genetic Algorithm: fitness = 0.7942: 100% 1000/1000 [00:00<00:00, 2983.66it/s]
# autoanchor: thr=0.25: 1.0000 best possible recall, 2.77 anchors past thr
# autoanchor: n=9, img_size=416, metric_all=0.244/0.794-mean/best, past_thr=0.546-mean: 44,6,  40,22,  132,33,  287,19,  36,223,  136,71,  32,367,  145,223,  153,376
# autoanchor: New anchors saved to model. Update model *.yaml to use these anchors in the future.
#
# Image sizes 416 train, 416 test
# Using 2 dataloader workers
# Logging results to runs/train/yolov5s_results
# Starting training for 200 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      0/199     1.78G    0.1093   0.03228   0.06736     0.209       116       416: 100% 2/2 [00:05<00:00,  2.75s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.64it/s]
#                  all           4          25    0.000833        0.15     0.00183    0.000588
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      1/199     1.78G     0.108   0.03811   0.06563    0.2117       142       416: 100% 2/2 [00:00<00:00,  2.01it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.03it/s]
#                  all           4          25    0.000781        0.15      0.0013    0.000391
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      2/199     1.78G    0.1109   0.03672   0.06625    0.2139       118       416: 100% 2/2 [00:00<00:00,  2.24it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.47it/s]
#                  all           4          25     0.00075        0.15      0.0013    0.000389
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      3/199     1.78G     0.109   0.04058   0.06577    0.2153       138       416: 100% 2/2 [00:00<00:00,  2.26it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.47it/s]
#                  all           4          25     0.00375       0.225      0.0277     0.00325
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      4/199     1.78G    0.1078   0.03779   0.06591    0.2115       117       416: 100% 2/2 [00:00<00:00,  2.26it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.20it/s]
#                  all           4          25     0.00275        0.25     0.00747     0.00192
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      5/199     1.78G    0.1079    0.0419   0.06584    0.2156       142       416: 100% 2/2 [00:00<00:00,  2.24it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.36it/s]
#                  all           4          25     0.00133         0.2     0.00224    0.000592
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      6/199     1.78G    0.1049   0.03754   0.06603    0.2085       144       416: 100% 2/2 [00:00<00:00,  2.32it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.41it/s]
#                  all           4          25     0.00116         0.2     0.00327    0.000833
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      7/199     1.78G    0.1055   0.04005   0.06528    0.2108       147       416: 100% 2/2 [00:00<00:00,  2.30it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.40it/s]
#                  all           4          25     0.00123         0.2     0.00363     0.00089
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      8/199     1.78G    0.1069   0.03732   0.06597    0.2102       124       416: 100% 2/2 [00:00<00:00,  2.32it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.52it/s]
#                  all           4          25    0.000588         0.1     0.00149    0.000221
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      9/199     1.78G     0.103   0.03824   0.06476     0.206       132       416: 100% 2/2 [00:00<00:00,  2.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.60it/s]
#                  all           4          25     0.00614        0.15     0.00657    0.000719
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     10/199     1.78G    0.1039   0.04128   0.06513    0.2103       135       416: 100% 2/2 [00:00<00:00,  2.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.06it/s]
#                  all           4          25    0.000526         0.1     0.00302    0.000384
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     11/199     1.78G    0.1032   0.04315   0.06547    0.2119       180       416: 100% 2/2 [00:00<00:00,  2.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.87it/s]
#                  all           4          25    0.000164       0.025    0.000209    4.19e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     12/199     1.78G    0.1016   0.04306   0.06494    0.2096       155       416: 100% 2/2 [00:00<00:00,  2.23it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.42it/s]
#                  all           4          25      0.0008        0.05    0.000464    4.64e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     13/199     1.78G    0.1045   0.03947   0.06531    0.2093       139       416: 100% 2/2 [00:00<00:00,  2.29it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.47it/s]
#                  all           4          25     0.00135         0.1     0.00216    0.000361
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     14/199     1.78G    0.1029   0.03967   0.06512    0.2077       144       416: 100% 2/2 [00:00<00:00,  2.25it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.57it/s]
#                  all           4          25     0.00125         0.1     0.00416    0.000416
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     15/199     1.78G    0.1013   0.04029   0.06459    0.2062       132       416: 100% 2/2 [00:00<00:00,  2.27it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.29it/s]
#                  all           4          25     0.00125         0.1      0.0014    0.000224
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     16/199     1.78G    0.1025   0.03767   0.06539    0.2056       135       416: 100% 2/2 [00:00<00:00,  2.25it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.33it/s]
#                  all           4          25     0.00125         0.1     0.00152    0.000205
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     17/199     1.78G    0.1014   0.04141    0.0645    0.2073       125       416: 100% 2/2 [00:00<00:00,  2.30it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.23it/s]
#                  all           4          25     0.00107       0.075     0.00113    0.000174
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     18/199     1.78G    0.1039   0.04211   0.06518    0.2111       153       416: 100% 2/2 [00:00<00:00,  2.32it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.41it/s]
#                  all           4          25     0.00107       0.075     0.00162    0.000244
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     19/199     1.78G    0.1023   0.04124   0.06446     0.208       154       416: 100% 2/2 [00:00<00:00,  2.30it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.92it/s]
#                  all           4          25     0.00107       0.075     0.00124    0.000151
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     20/199     1.78G    0.1031   0.04239   0.06436    0.2098       147       416: 100% 2/2 [00:00<00:00,  2.29it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.95it/s]
#                  all           4          25     0.00107       0.075       0.001    0.000123
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     21/199     1.78G    0.1015   0.04287   0.06413    0.2085       108       416: 100% 2/2 [00:00<00:00,  2.33it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.51it/s]
#                  all           4          25     0.00109       0.075     0.00401    0.000447
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     22/199     1.78G    0.1002    0.0383   0.06415    0.2026       125       416: 100% 2/2 [00:00<00:00,  2.28it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.11it/s]
#                  all           4          25     0.00107       0.075     0.00174    0.000217
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     23/199     1.78G    0.1009   0.03807    0.0639    0.2029       112       416: 100% 2/2 [00:00<00:00,  2.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.10it/s]
#                  all           4          25     0.00107       0.075     0.00242    0.000283
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     24/199     1.78G    0.1014   0.04582   0.06357    0.2108       157       416: 100% 2/2 [00:00<00:00,  2.30it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.47it/s]
#                  all           4          25     0.00111       0.075     0.00152    0.000203
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     25/199     1.78G     0.102   0.04295   0.06328    0.2082       123       416: 100% 2/2 [00:00<00:00,  2.26it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.00it/s]
#                  all           4          25    0.000709        0.05    0.000846    0.000118
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     26/199     1.78G    0.1018   0.04218   0.06384    0.2078       133       416: 100% 2/2 [00:00<00:00,  2.26it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.15it/s]
#                  all           4          25    0.000704        0.05    0.000472    8.27e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     27/199     1.78G     0.102   0.03933   0.06471     0.206       125       416: 100% 2/2 [00:00<00:00,  2.26it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.94it/s]
#                  all           4          25    0.000714        0.05    0.000667    0.000117
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     28/199     1.78G    0.1004   0.04062   0.06337    0.2044       129       416: 100% 2/2 [00:00<00:00,  2.32it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.29it/s]
#                  all           4          25     0.00118         0.1     0.00771    0.000976
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     29/199     1.78G    0.1004   0.04212   0.06389    0.2064       147       416: 100% 2/2 [00:00<00:00,  2.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.59it/s]
#                  all           4          25    0.000722        0.05    0.000861    0.000157
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     30/199     1.78G    0.1024   0.03601   0.06326    0.2016       144       416: 100% 2/2 [00:00<00:00,  2.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.05it/s]
#                  all           4          25     0.00109         0.1     0.00103    0.000177
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     31/199     1.78G    0.1008   0.04467   0.06336    0.2089       155       416: 100% 2/2 [00:00<00:00,  2.35it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.26it/s]
#                  all           4          25    0.000358       0.025     0.00245    0.000736
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     32/199     1.78G    0.1015   0.04507   0.06323    0.2098       165       416: 100% 2/2 [00:00<00:00,  2.30it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.79it/s]
#                  all           4          25     0.00159       0.075     0.00883     0.00252
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     33/199     1.78G    0.1022   0.04321   0.06363    0.2091       137       416: 100% 2/2 [00:00<00:00,  2.22it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.45it/s]
#                  all           4          25    0.000357       0.025     0.00102    0.000307
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     34/199     1.78G    0.1021   0.04464   0.06292    0.2097       143       416: 100% 2/2 [00:00<00:00,  2.20it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.59it/s]
#                  all           4          25    0.000372       0.025    0.000616    0.000185
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     35/199     1.78G     0.102   0.04508   0.06291      0.21       165       416: 100% 2/2 [00:00<00:00,  2.28it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.39it/s]
#                  all           4          25     0.00145       0.075     0.00146    0.000226
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     36/199     1.78G    0.1023   0.04431   0.06276    0.2094       147       416: 100% 2/2 [00:00<00:00,  2.29it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.47it/s]
#                  all           4          25    0.000357       0.025     0.00107    0.000321
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     37/199     1.78G    0.1012   0.04138   0.06294    0.2056       148       416: 100% 2/2 [00:00<00:00,  2.29it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.39it/s]
#                  all           4          25     0.00118       0.075     0.00132    0.000212
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     38/199     1.78G    0.1002   0.04349   0.06285    0.2065       136       416: 100% 2/2 [00:00<00:00,  2.29it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.23it/s]
#                  all           4          25    0.000362       0.025    0.000273    8.19e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     39/199     1.78G    0.1008   0.03908   0.06278    0.2027       136       416: 100% 2/2 [00:00<00:00,  2.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.21it/s]
#                  all           4          25    0.000375       0.025    0.000354    7.07e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     40/199     1.78G    0.1015   0.03996   0.06291    0.2044       158       416: 100% 2/2 [00:00<00:00,  2.24it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.80it/s]
#                  all           4          25     0.00117       0.075    0.000768    0.000182
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     41/199     1.78G    0.1017   0.04063   0.06245    0.2048       141       416: 100% 2/2 [00:00<00:00,  2.28it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.36it/s]
#                  all           4          25    0.000379       0.025     0.00307     0.00092
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     42/199     1.78G    0.1025   0.04218    0.0638    0.2085       159       416: 100% 2/2 [00:00<00:00,  2.27it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.52it/s]
#                  all           4          25    0.000377       0.025    0.000393    0.000118
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     43/199     1.78G   0.09954   0.04147   0.06275    0.2038       132       416: 100% 2/2 [00:00<00:00,  2.27it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.29it/s]
#                  all           4          25    0.000917       0.075     0.00599    0.000845
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     44/199     1.78G   0.09935   0.04157   0.06246    0.2034       110       416: 100% 2/2 [00:00<00:00,  2.29it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.34it/s]
#                  all           4          25    0.000924       0.075     0.00216    0.000489
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     45/199     1.78G    0.1005   0.04109   0.06278    0.2043       141       416: 100% 2/2 [00:00<00:00,  2.27it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.82it/s]
#                  all           4          25    0.000927       0.075     0.00281    0.000632
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     46/199     1.78G    0.1005   0.04598   0.06202    0.2085       129       416: 100% 2/2 [00:00<00:00,  2.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.79it/s]
#                  all           4          25    0.000917       0.075    0.000898    0.000172
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     47/199     1.78G   0.09964   0.03995    0.0619    0.2015       141       416: 100% 2/2 [00:00<00:00,  2.25it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.57it/s]
#                  all           4          25    0.000383       0.025     0.00223    0.000669
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     48/199     1.78G    0.1007   0.04061   0.06209    0.2034       128       416: 100% 2/2 [00:00<00:00,  2.26it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.19it/s]
#                  all           4          25    0.000903       0.075     0.00209    0.000418
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     49/199     1.78G   0.09833   0.03663   0.06211    0.1971       127       416: 100% 2/2 [00:00<00:00,  2.28it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.27it/s]
#                  all           4           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     50/199     1.78G   0.09866   0.04124   0.06214     0.202       172       416: 100% 2/2 [00:00<00:00,  2.22it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.11it/s]
#                  all           4          25    0.000923       0.075    0.000886    0.000177
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     51/199     1.78G   0.09701   0.04498   0.06135    0.2033       135       416: 100% 2/2 [00:00<00:00,  2.26it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.24it/s]
#                  all           4          25    0.000518        0.05    0.000344    3.44e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     52/199     1.78G       0.1   0.03645   0.06227    0.1987       100       416: 100% 2/2 [00:00<00:00,  2.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.07it/s]
#                  all           4          25      0.0004       0.025    0.000306    6.13e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     53/199     1.78G    0.1003   0.04308   0.06203    0.2054       174       416: 100% 2/2 [00:00<00:00,  2.29it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.70it/s]
#                  all           4          25    0.000917       0.075    0.000598     0.00012
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     54/199     1.78G   0.09977   0.04133    0.0611    0.2022       128       416: 100% 2/2 [00:00<00:00,  2.28it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.56it/s]
#                  all           4          25    0.000916       0.075    0.000742    0.000148
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     55/199     1.78G   0.09833   0.04188   0.06172    0.2019       127       416: 100% 2/2 [00:00<00:00,  2.29it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.44it/s]
#                  all           4          25    0.000388       0.025    0.000246    4.93e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     56/199     1.78G   0.09781   0.04561   0.06109    0.2045       143       416: 100% 2/2 [00:00<00:00,  2.30it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.38it/s]
#                  all           4          25    0.000911       0.075    0.000532    0.000106
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     57/199     1.78G   0.09853   0.04623   0.06168    0.2064       176       416: 100% 2/2 [00:00<00:00,  2.22it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.30it/s]
#                  all           4          25    0.000922       0.075    0.000562    0.000112
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     58/199     1.78G   0.09923   0.04215   0.06101    0.2024       150       416: 100% 2/2 [00:00<00:00,  2.34it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.49it/s]
#                  all           4          25    0.000916       0.075    0.000562    8.14e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     59/199     1.78G   0.09916   0.04306   0.06109    0.2033       155       416: 100% 2/2 [00:00<00:00,  2.23it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.29it/s]
#                  all           4          25    0.000925       0.075    0.000593    8.58e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     60/199     1.78G       0.1   0.04461    0.0607    0.2053       134       416: 100% 2/2 [00:00<00:00,  2.30it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.18it/s]
#                  all           4          25    0.000912       0.075    0.000677    0.000102
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     61/199     1.78G    0.1001   0.03855   0.06125    0.1999       124       416: 100% 2/2 [00:00<00:00,  2.29it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.56it/s]
#                  all           4          25       0.201       0.025    0.000793    0.000123
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     62/199     1.78G   0.09879    0.0424   0.06054    0.2017       155       416: 100% 2/2 [00:00<00:00,  2.27it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.64it/s]
#                  all           4          25    0.000508        0.05    0.000337    3.37e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     63/199     1.78G   0.09731   0.04484   0.06118    0.2033       129       416: 100% 2/2 [00:00<00:00,  2.36it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.90it/s]
#                  all           4           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     64/199     1.78G   0.09828   0.04524   0.06056    0.2041       141       416: 100% 2/2 [00:00<00:00,  2.27it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.87it/s]
#                  all           4           0           0           0           0           0
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     65/199     1.78G   0.09964    0.0482   0.06033    0.2082       166       416: 100% 2/2 [00:00<00:00,  2.28it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.80it/s]
#                  all           4          25    0.000397       0.025     0.00107    0.000214
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     66/199     1.78G   0.09959   0.04423   0.06085    0.2047       155       416: 100% 2/2 [00:00<00:00,  2.29it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.16it/s]
#                  all           4          25    0.000392       0.025     0.00154    0.000307
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     67/199     1.78G   0.09802   0.04384   0.06055    0.2024       154       416: 100% 2/2 [00:00<00:00,  2.30it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.23it/s]
#                  all           4          25    0.000905       0.075     0.00258    0.000394
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     68/199     1.78G   0.09963   0.03804   0.06052    0.1982       107       416: 100% 2/2 [00:00<00:00,  2.24it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.01it/s]
#                  all           4          25    0.000921       0.075    0.000711    9.93e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     69/199     1.78G   0.09791   0.04634   0.06094    0.2052       144       416: 100% 2/2 [00:00<00:00,  2.27it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.50it/s]
#                  all           4          25     0.00038       0.025    0.000548     0.00011
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     70/199     1.78G   0.09929   0.04205   0.06035    0.2017       162       416: 100% 2/2 [00:00<00:00,  2.27it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.90it/s]
#                  all           4          25         0.3       0.025    0.000251    5.02e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     71/199     1.78G    0.0986   0.04286   0.06059     0.202       136       416: 100% 2/2 [00:00<00:00,  2.25it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.32it/s]
#                  all           4          25         0.3       0.025    0.000126    3.79e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     72/199     1.78G   0.09595   0.04579   0.05946    0.2012       134       416: 100% 2/2 [00:00<00:00,  2.28it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.64it/s]
#                  all           4          25         0.5       0.025    0.000131    2.62e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     73/199     1.78G    0.1002   0.04155   0.06123     0.203       146       416: 100% 2/2 [00:00<00:00,  2.26it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 12.02it/s]
#                  all           4          25         0.2       0.025    0.000441    4.41e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     74/199     1.78G   0.09752   0.04474   0.05993    0.2022       146       416: 100% 2/2 [00:00<00:00,  2.33it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.57it/s]
#                  all           4          25         0.4       0.025     0.00136    0.000409
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     75/199     1.78G   0.09732   0.04046   0.06024     0.198       116       416: 100% 2/2 [00:00<00:00,  2.28it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.88it/s]
#                  all           4          25         0.2       0.025     0.00129    0.000388
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     76/199     1.78G   0.09788   0.04608   0.05973    0.2037       168       416: 100% 2/2 [00:00<00:00,  2.32it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.65it/s]
#                  all           4          25       0.101        0.05    0.000539    0.000117
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     77/199     1.78G   0.09932   0.03961   0.05985    0.1988       117       416: 100% 2/2 [00:00<00:00,  2.28it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.28it/s]
#                  all           4          25       0.201        0.05    0.000388    0.000102
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     78/199     1.78G   0.09642   0.04322   0.05994    0.1996       128       416: 100% 2/2 [00:00<00:00,  2.22it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.85it/s]
#                  all           4          25    0.000719       0.075    0.000469    6.03e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     79/199     1.78G   0.09882   0.04623   0.05962    0.2047       158       416: 100% 2/2 [00:00<00:00,  2.29it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.82it/s]
#                  all           4          25    0.000927       0.075     0.00257    0.000278
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     80/199     1.78G   0.09587   0.03537   0.06036    0.1916        80       416: 100% 2/2 [00:00<00:00,  2.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.78it/s]
#                  all           4          25    0.000851       0.075      0.0025     0.00025
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     81/199     1.78G   0.09917   0.04134    0.0593    0.1998       112       416: 100% 2/2 [00:00<00:00,  2.28it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.57it/s]
#                  all           4          25    0.000705        0.05    0.000539    5.39e-05
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     82/199     1.78G   0.09826   0.04448   0.05932    0.2021       144       416: 100% 2/2 [00:00<00:00,  2.30it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.87it/s]
#                  all           4          25       0.649       0.025      0.0258     0.00517
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     83/199     1.78G   0.09481   0.04815   0.05933    0.2023       162       416: 100% 2/2 [00:00<00:00,  2.36it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.50it/s]
#                  all           4          25       0.207       0.025     0.00676     0.00135
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     84/199     1.78G   0.09709   0.04414   0.05953    0.2008       149       416: 100% 2/2 [00:00<00:00,  2.37it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.05it/s]
#                  all           4          25    0.000784       0.075    0.000883    0.000202
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     85/199     1.78G   0.09659   0.04132   0.05964    0.1976       129       416: 100% 2/2 [00:00<00:00,  2.35it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.71it/s]
#                  all           4          25       0.102        0.05     0.00258     0.00067
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     86/199     1.78G   0.09908   0.05074   0.05851    0.2083       184       416: 100% 2/2 [00:00<00:00,  2.32it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.39it/s]
#                  all           4          25       0.417       0.025     0.00979    0.000998
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     87/199     1.78G   0.09894   0.04265   0.05933    0.2009       115       416: 100% 2/2 [00:00<00:00,  2.38it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.65it/s]
#                  all           4          25     0.00187       0.125     0.00434    0.000505
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     88/199     1.78G   0.09755    0.0404   0.05953    0.1975       108       416: 100% 2/2 [00:00<00:00,  2.42it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.16it/s]
#                  all           4          25     0.00133        0.05     0.00241    0.000271
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     89/199     1.78G   0.09845   0.04327   0.05899    0.2007       156       416: 100% 2/2 [00:00<00:00,  2.40it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.35it/s]
#                  all           4          25     0.00467         0.1     0.00278    0.000505
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     90/199     1.78G   0.09991   0.04284   0.05904    0.2018       129       416: 100% 2/2 [00:00<00:00,  2.39it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.86it/s]
#                  all           4          25       0.105       0.025     0.00387     0.00103
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     91/199     1.78G   0.09607   0.04773   0.05915    0.2029       124       416: 100% 2/2 [00:00<00:00,  2.35it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.79it/s]
#                  all           4          25       0.117       0.025     0.00573     0.00064
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     92/199     1.78G    0.0958   0.04179   0.05843     0.196       131       416: 100% 2/2 [00:00<00:00,  2.41it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.51it/s]
#                  all           4          25     0.00107        0.05     0.00104    0.000383
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     93/199     1.78G    0.0963   0.05137   0.05956    0.2072       161       416: 100% 2/2 [00:00<00:00,  2.43it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.17it/s]
#                  all           4          25       0.994       0.025      0.0272     0.00281
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     94/199     1.78G   0.09908   0.04436   0.05878    0.2022       161       416: 100% 2/2 [00:00<00:00,  2.39it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.44it/s]
#                  all           4          25       0.241       0.025        0.02      0.0035
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     95/199     1.78G   0.09708   0.04589   0.05867    0.2016       160       416: 100% 2/2 [00:00<00:00,  2.36it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.08it/s]
#                  all           4          25       0.156       0.025      0.0291     0.00299
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     96/199     1.78G   0.09556   0.04343   0.05927    0.1983       105       416: 100% 2/2 [00:00<00:00,  2.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.27it/s]
#                  all           4          25       0.104       0.025     0.00398    0.000578
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     97/199     1.78G   0.09847   0.04688   0.05859    0.2039       160       416: 100% 2/2 [00:00<00:00,  2.41it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.46it/s]
#                  all           4          25       0.115      0.0232     0.00593      0.0022
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     98/199     1.78G   0.09914   0.04058   0.05886    0.1986       114       416: 100% 2/2 [00:00<00:00,  2.45it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.04it/s]
#                  all           4          25      0.0181       0.025     0.00989     0.00196
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
# ...
#                  all           4          25       0.005         0.1     0.00228    0.000257
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    165/199     1.78G   0.09833   0.04022   0.05783    0.1964        96       416: 100% 2/2 [00:00<00:00,  2.37it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.17it/s]
#                  all           4          25     0.00575       0.125      0.0062     0.00142
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    166/199     1.78G   0.09618   0.04987   0.05611    0.2022       159       416: 100% 2/2 [00:00<00:00,  2.43it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.35it/s]
#                  all           4          25       0.115       0.025     0.00847     0.00126
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    167/199     1.78G   0.09518   0.04796   0.05725    0.2004       141       416: 100% 2/2 [00:00<00:00,  2.38it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.34it/s]
#                  all           4          25     0.00115       0.075     0.00074    0.000199
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    168/199     1.78G   0.09684   0.04644   0.05602    0.1993       169       416: 100% 2/2 [00:00<00:00,  2.37it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.06it/s]
#                  all           4          25      0.0109       0.025     0.00422    0.000468
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    169/199     1.78G   0.09571   0.04352    0.0572    0.1964       117       416: 100% 2/2 [00:00<00:00,  2.41it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.52it/s]
#                  all           4          25     0.00213       0.025    0.000995    0.000199
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    170/199     1.78G   0.09595   0.05015   0.05642    0.2025       177       416: 100% 2/2 [00:00<00:00,  2.35it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.49it/s]
#                  all           4          25     0.00321        0.15     0.00329    0.000337
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    171/199     1.78G   0.09687   0.04144   0.05642    0.1947       144       416: 100% 2/2 [00:00<00:00,  2.39it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.23it/s]
#                  all           4          25     0.00242       0.025     0.00182    0.000408
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    172/199     1.78G   0.09633   0.05011   0.05684    0.2033       135       416: 100% 2/2 [00:00<00:00,  2.35it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.32it/s]
#                  all           4          25     0.00683       0.025     0.00248    0.000744
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    173/199     1.78G   0.09786   0.04579   0.05599    0.1996       185       416: 100% 2/2 [00:00<00:00,  2.42it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.15it/s]
#                  all           4          25      0.0108       0.025     0.00345     0.00165
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    174/199     1.78G   0.09622   0.04102   0.05633    0.1936       105       416: 100% 2/2 [00:00<00:00,  2.33it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.68it/s]
#                  all           4          25     0.00134       0.075     0.00112    0.000467
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    175/199     1.78G   0.09687    0.0428   0.05652    0.1962       117       416: 100% 2/2 [00:00<00:00,  2.44it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.29it/s]
#                  all           4          25      0.0017         0.1     0.00197    0.000241
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    176/199     1.78G   0.09665   0.04868   0.05715    0.2025       161       416: 100% 2/2 [00:00<00:00,  2.41it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.95it/s]
#                  all           4          25     0.00209        0.15      0.0021    0.000355
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    177/199     1.78G   0.09712   0.04293    0.0573    0.1973       162       416: 100% 2/2 [00:00<00:00,  2.37it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.57it/s]
#                  all           4          25      0.0026       0.025     0.00212    0.000389
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    178/199     1.78G   0.09539   0.04374   0.05706    0.1962       113       416: 100% 2/2 [00:00<00:00,  2.37it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.30it/s]
#                  all           4          25     0.00502       0.025      0.0035    0.000415
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    179/199     1.78G    0.0958   0.04336   0.05681     0.196       136       416: 100% 2/2 [00:00<00:00,  2.41it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.04it/s]
#                  all           4          25     0.00237       0.025     0.00327    0.000421
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    180/199     1.78G   0.09629   0.04221   0.05676    0.1952       103       416: 100% 2/2 [00:00<00:00,  2.38it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.74it/s]
#                  all           4          25     0.00169         0.1     0.00142     0.00016
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    181/199     1.78G   0.09698   0.03831   0.05623    0.1915       135       416: 100% 2/2 [00:00<00:00,  2.39it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.85it/s]
#                  all           4          25     0.00386       0.125     0.00288    0.000744
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    182/199     1.78G   0.09559   0.04055   0.05707    0.1932       120       416: 100% 2/2 [00:00<00:00,  2.39it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.88it/s]
#                  all           4          25     0.00398         0.1     0.00422     0.00046
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    183/199     1.78G   0.09979    0.0408   0.05628    0.1969       156       416: 100% 2/2 [00:00<00:00,  2.43it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.14it/s]
#                  all           4          25     0.00197       0.025     0.00191    0.000279
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    184/199     1.78G   0.09582   0.04265   0.05734    0.1958       108       416: 100% 2/2 [00:00<00:00,  2.38it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.90it/s]
#                  all           4          25     0.00543        0.15     0.00406    0.000612
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    185/199     1.78G   0.09729   0.04497   0.05573     0.198       162       416: 100% 2/2 [00:00<00:00,  2.38it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.96it/s]
#                  all           4          25     0.00316      0.0957     0.00211    0.000474
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    186/199     1.78G   0.09568   0.04574   0.05684    0.1983       127       416: 100% 2/2 [00:00<00:00,  2.36it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.10it/s]
#                  all           4          25     0.00255      0.0919     0.00215    0.000365
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    187/199     1.78G   0.09582    0.0389   0.05647    0.1912       102       416: 100% 2/2 [00:00<00:00,  2.39it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.81it/s]
#                  all           4          25     0.00137        0.05     0.00153    0.000262
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    188/199     1.78G   0.09625    0.0415   0.05701    0.1948       126       416: 100% 2/2 [00:00<00:00,  2.38it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.14it/s]
#                  all           4          25     0.00163         0.1     0.00198     0.00032
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    189/199     1.78G   0.09685   0.04776   0.05649    0.2011       169       416: 100% 2/2 [00:00<00:00,  2.33it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.45it/s]
#                  all           4          25     0.00101       0.075    0.000844    0.000149
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    190/199     1.78G   0.09635   0.04645   0.05751    0.2003       151       416: 100% 2/2 [00:00<00:00,  2.39it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.72it/s]
#                  all           4          25     0.00295        0.05     0.00324    0.000406
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    191/199     1.78G   0.09797   0.04558   0.05666    0.2002       136       416: 100% 2/2 [00:00<00:00,  2.38it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.64it/s]
#                  all           4          25       0.118       0.025     0.00581     0.00265
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    192/199     1.78G   0.09585   0.04372   0.05638     0.196       118       416: 100% 2/2 [00:00<00:00,  2.31it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.13it/s]
#                  all           4          25      0.0099         0.1      0.0065    0.000905
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    193/199     1.78G   0.09585   0.04364   0.05632    0.1958       140       416: 100% 2/2 [00:00<00:00,  2.41it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.24it/s]
#                  all           4          25       0.195      0.0704      0.0551     0.00592
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    194/199     1.78G    0.0968   0.04768    0.0568    0.2013       187       416: 100% 2/2 [00:00<00:00,  2.40it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.91it/s]
#                  all           4          25     0.00326       0.125     0.00419    0.000445
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    195/199     1.78G   0.09802   0.04476   0.05592    0.1987       130       416: 100% 2/2 [00:00<00:00,  2.38it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.13it/s]
#                  all           4          25     0.00196       0.025     0.00207     0.00044
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    196/199     1.78G   0.09704   0.04491   0.05664    0.1986       142       416: 100% 2/2 [00:00<00:00,  2.38it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.07it/s]
#                  all           4          25     0.00743       0.025     0.00589    0.000589
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    197/199     1.78G   0.09554   0.04396   0.05548     0.195       182       416: 100% 2/2 [00:00<00:00,  2.34it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.82it/s]
#                  all           4          25      0.0193       0.025     0.00717     0.00268
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    198/199     1.78G   0.09957   0.03544   0.05756    0.1926       121       416: 100% 2/2 [00:00<00:00,  2.45it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.05it/s]
#                  all           4          25     0.00538        0.05     0.00386    0.000603
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    199/199     1.78G   0.09585   0.04275    0.0562    0.1948       132       416: 100% 2/2 [00:00<00:00,  2.37it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.56it/s]
#                  all           4          25       0.217      0.0248     0.00735     0.00134
#       Account Number           4           2           0           0           0           0
#         Account Type           4           2           0           0           0           0
#              Balance           4           4           1           0     0.00469    0.000469
#              Credits           4           2           0           0           0           0
#               Debits           4           2           0           0           0           0
#             Deposits           4           2           1           0           0           0
#                 Name           4           2           0           0           0           0
#        Total Balance           4           3           0           0           0           0
# Transaction Particulars           4           4       0.166       0.248      0.0688       0.013
#          Withdrawals           4           2           0           0           0           0
# Optimizer stripped from runs/train/yolov5s_results/weights/last.pt, 14.8MB
# Optimizer stripped from runs/train/yolov5s_results/weights/best.pt, 14.8MB
# 200 epochs completed in 0.084 hours.
#
# CPU times: user 3.92 s, sys: 624 ms, total: 4.54 s
# Wall time: 5min 26s

# %%
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results/results.png', width=1000)

# %%
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/test_batch0_labels.jpg', width=900)
# Out:
# GROUND TRUTH TRAINING DATA:

# %%
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results/train_batch0.jpg', width=900)
# Out:
# GROUND TRUTH AUGMENTED TRAINING DATA:
